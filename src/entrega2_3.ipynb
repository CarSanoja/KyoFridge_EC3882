# %%
# %matplotlib notebook
#The libraries we are going to use are PySerial and Time
# PySerial is encapsulates the access for the serial port.
import serial
import time
import numpy as np
# script that allow to set the graphs for the signal
#from graph import *
# Matplotlib to draw functions
import matplotlib.pyplot as plt
# To allow make live data graph we need drawnow
# pip install drawnow
# Librerias para graficar
import matplotlib.animation as animation
from IPython.display import HTML



file = open("Generator_data.txt","r")
file_read = file.read()
file_splitted = file_read.split("\n")
len_file = len(file_splitted)

file2 = open("time_data.txt","r")
file2_read = file2.read()
file2_splitted = file2_read.split("\n")


def next():
    i = 0
    while i <= len_file:
        i += 1
        yield i


def update(i):
    if i >=99:
        xdata.pop(0)
        ydata.pop(0)
        xdata.append(float(file2_splitted[i]))
        y = int(file_splitted[i])
        ydata.append(y)
        ax.set_xlim(min(xdata), max(xdata)) 
    else:
        xdata.append(float(file2_splitted[i]))
        y = int(file_splitted[i])
        ydata.append(y)
        line.set_data(xdata, ydata)
        #ax.set_xlim(min(xdata), max(xdata))
    return line,


fig, ax = plt.subplots()
line, = ax.plot([], [])
xdata = []
ydata = []
ax.set_ylim([-0.5, 3])
ax.set_xlim(0, 1) 

a = animation.FuncAnimation(fig, update, next, blit = False, interval = 10, repeat = False)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">
# <img src="data:image/png;base64,..." width="432">

# %%
# %matplotlib inline
#The libraries we are going to use are PySerial and Time
# PySerial is encapsulates the access for the serial port.
import serial
import time
import numpy as np
# script that allow to set the graphs for the signal
#from graph import *
# Matplotlib to draw functions
import matplotlib.pyplot as plt
# To allow make live data graph we need drawnow
# pip install drawnow
# Librerias para graficar
import matplotlib.animation as animation
from IPython.display import HTML

# %%
file = open("Generator_data.txt","r")
file_read = file.read()
file_splitted = file_read.split("\n")
len_file = len(file_splitted)

file2 = open("time_data.txt","r")
file2_read = file2.read()
file2_splitted = file2_read.split("\n")

# %%
plt.plot(file2_splitted[100:200],file_splitted[100:200])
